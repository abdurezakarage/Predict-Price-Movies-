# %%
import sys 
import os
import pandas as pd
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from src.quantitative_analysis import QuantitativeAnalyzer

# %%
analyzer = QuantitativeAnalyzer("AAPL", period="6mo", interval="1d")

# %%
success = analyzer.load_stock_data()
if success:
    display(analyzer.stock_data.head())
# Out:
# 2025-08-16 09:31:34,509 - INFO - Loading stock data for AAPL...
# 2025-08-16 09:31:38,303 - INFO - Successfully loaded 125 data points for AAPL
# 2025-08-16 09:31:38,319 - INFO - Date range: 2025-02-18 00:00:00-05:00 to 2025-08-15 00:00:00-04:00
#                                  Open        High         Low       Close  \
# Date
# 2025-02-18 00:00:00-05:00  243.553836  244.581320  241.249479  243.873062
# 2025-02-19 00:00:00-05:00  244.062601  245.409295  242.566263  244.272079
# 2025-02-20 00:00:00-05:00  244.341925  246.177429  243.693503  245.229752
# 2025-02-21 00:00:00-05:00  245.349441  248.082756  244.621228  244.950424
# 2025-02-24 00:00:00-05:00  244.331928  248.252340  243.823179  246.496643
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-02-18 00:00:00-05:00  48822500        0.0           0.0
# 2025-02-19 00:00:00-05:00  32204200        0.0           0.0
# 2025-02-20 00:00:00-05:00  32316900        0.0           0.0
# 2025-02-21 00:00:00-05:00  53197400        0.0           0.0
# 2025-02-24 00:00:00-05:00  51326400        0.0           0.0

# %%
# Test the fixed technical indicators calculation
print("Testing technical indicators calculation with debug info...")

# Enable debug logging temporarily 
import logging
logging.getLogger().setLevel(logging.DEBUG)

indicators = analyzer.calculate_technical_indicators()

# Reset logging level
logging.getLogger().setLevel(logging.INFO)

if indicators:
    print(f"\nSuccessfully calculated {len(indicators)} indicators!")
    print("First 10 indicator names:")
    print(list(indicators.keys())[:10])
    
    # Show some sample values
    print("\nSample RSI values (last 5):")
    if 'RSI' in indicators:
        rsi_values = indicators['RSI']
        print(rsi_values[-5:])
else:
    print("Failed to calculate indicators")
# Out:
# 2025-08-16 09:35:18,860 - INFO - Calculating technical indicators...
# 2025-08-16 09:35:18,871 - DEBUG - Original data types: Open=float64, Close=float64
# 2025-08-16 09:35:18,877 - DEBUG - Converted data types: open_prices=float64, close_prices=float64
# 2025-08-16 09:35:18,878 - DEBUG - Array shapes: open=(125,), close=(125,)
# 2025-08-16 09:35:18,885 - INFO - Successfully calculated 30 technical indicators
# Testing technical indicators calculation with debug info...
#
# Successfully calculated 30 indicators!
# First 10 indicator names:
# ['SMA_20', 'SMA_50', 'SMA_200', 'EMA_12', 'EMA_26', 'RSI', 'STOCH_K', 'STOCH_D', 'WILLR', 'CCI']
#
# Sample RSI values (last 5):
# [70.24333505 72.04930419 74.52957203 73.48008605 71.14574461]

# %%
analyzer.create_comprehensive_visualizations()
# Out:
# 2025-08-16 09:35:23,959 - INFO - Creating comprehensive visualizations...
# 2025-08-16 09:35:25,545 - INFO - Chromium init'ed with kwargs {}
# 2025-08-16 09:35:25,550 - INFO - Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# 2025-08-16 09:35:25,554 - INFO - Temp directory created: C:\Users\abdur\AppData\Local\Temp\tmplm1wv_jf.
# 2025-08-16 09:35:25,558 - INFO - Opening browser.
# 2025-08-16 09:35:25,563 - INFO - Temp directory created: C:\Users\abdur\AppData\Local\Temp\tmpogakueol.
# 2025-08-16 09:35:25,571 - INFO - Temporary directory at: C:\Users\abdur\AppData\Local\Temp\tmpogakueol
# 2025-08-16 09:35:27,110 - INFO - Conforming 1 to file:///C:/Users/abdur/AppData/Local/Temp/tmplm1wv_jf/index.html
# 2025-08-16 09:35:27,112 - INFO - Waiting on all navigates
# 2025-08-16 09:35:32,942 - INFO - All navigates done, putting them all in queue.
# 2025-08-16 09:35:32,950 - INFO - Getting tab from queue (has 1)
# 2025-08-16 09:35:32,953 - INFO - Got 2595
# 2025-08-16 09:35:32,954 - INFO - Processing Comprehensive_Technical_Analysis_for_AAPL.png
# 2025-08-16 09:35:32,956 - INFO - Sending big command for Comprehensive_Technical_Analysis_for_AAPL.png.
# 2025-08-16 09:35:34,966 - INFO - Sent big command for Comprehensive_Technical_Analysis_for_AAPL.png.
# 2025-08-16 09:35:34,980 - INFO - Reloading tab 2595 before return.
# 2025-08-16 09:35:37,146 - INFO - Putting tab 2595 back (queue size: 0).
# 2025-08-16 09:35:37,149 - INFO - Waiting for all cleanups to finish.
# 2025-08-16 09:35:37,150 - INFO - Exiting Kaleido
# 2025-08-16 09:35:37,160 - INFO - TemporaryDirectory.cleanup() worked.
# 2025-08-16 09:35:37,165 - INFO - shutil.rmtree worked.
# 2025-08-16 09:35:37,167 - INFO - Cancelling tasks.
# 2025-08-16 09:35:37,169 - INFO - Exiting Kaleido/Choreo
# 2025-08-16 09:35:37,170 - INFO - Closing browser.
# 2025-08-16 09:35:37,193 - INFO - TemporaryDirectory.cleanup() worked.
# 2025-08-16 09:35:37,196 - INFO - shutil.rmtree worked.
# 2025-08-16 09:35:37,199 - INFO - Cancelling tasks.
# 2025-08-16 09:35:37,200 - INFO - Exiting Kaleido/Choreo
# 2025-08-16 09:35:37,202 - INFO - Closing browser.
# 2025-08-16 09:35:40,332 - WARNING - Resorting to unclean kill browser.
# 2025-08-16 09:35:41,334 - INFO - TemporaryDirectory.cleanup() worked.
# 2025-08-16 09:35:41,338 - INFO - shutil.rmtree worked.
# 2025-08-16 09:35:41,351 - INFO - Comprehensive visualizations saved: ../visualizations\AAPL_comprehensive_analysis.html
# 2025-08-16 09:35:41,354 - INFO - PNG version saved: ../visualizations\AAPL_comprehensive_analysis.png

# %%
metrics = analyzer.calculate_financial_metrics()
pd.DataFrame(metrics.items(), columns=["Metric", "Value"])
# Out:
# 2025-08-16 09:35:55,970 - INFO - Calculating financial metrics...
# 2025-08-16 09:35:55,976 - INFO - Successfully calculated 19 financial metrics
#                       Metric         Value
# 0                 price_mean  2.113676e+02
# 1                  price_std  1.447452e+01
# 2                  price_min  1.719990e+02
# 3                  price_max  2.464966e+02
# 4                price_range  7.449767e+01
# 5          daily_return_mean -1.059858e-04
# 6           daily_return_std  2.524240e-02
# 7      annualized_volatility  4.007107e-01
# 8               sharpe_ratio -6.665262e-02
# 9               max_drawdown -3.022259e-01
# 10                    var_95 -3.726762e-02
# 11               volume_mean  5.870745e+07
# 12                volume_std  2.500573e+07
# 13  price_volume_correlation -3.333516e-01
# 14            high_low_ratio  1.026516e+00
# 15          close_open_ratio  1.001061e+00
# 16            trend_strength           NaN
# 17               momentum_5d  1.091267e-02
# 18              momentum_20d  9.789201e-02

# %%
symbols = ["MSFT", "GOOGL"]

for sym in symbols:
    print(f"\n===== {sym} =====")
    an = QuantitativeAnalyzer(sym, period="6mo", interval="1d")
    if an.load_stock_data():
        an.calculate_technical_indicators()
        an.calculate_financial_metrics()
        an.create_comprehensive_visualizations()
# Out:
# 2025-08-16 09:35:59,853 - INFO - Loading stock data for MSFT...
# ===== MSFT =====
# 2025-08-16 09:36:05,320 - INFO - Successfully loaded 125 data points for MSFT
# 2025-08-16 09:36:05,322 - INFO - Date range: 2025-02-18 00:00:00-05:00 to 2025-08-15 00:00:00-04:00
# 2025-08-16 09:36:05,323 - INFO - Calculating technical indicators...
# 2025-08-16 09:36:05,327 - INFO - Successfully calculated 30 technical indicators
# 2025-08-16 09:36:05,330 - INFO - Calculating financial metrics...
# 2025-08-16 09:36:05,337 - INFO - Successfully calculated 19 financial metrics
# 2025-08-16 09:36:05,338 - INFO - Creating comprehensive visualizations...
# 2025-08-16 09:36:05,350 - INFO - TemporaryDirectory.cleanup() worked.
# 2025-08-16 09:36:05,353 - INFO - shutil.rmtree worked.
# 2025-08-16 09:36:05,615 - INFO - Chromium init'ed with kwargs {}
# 2025-08-16 09:36:05,622 - INFO - Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# 2025-08-16 09:36:05,623 - INFO - Temp directory created: C:\Users\abdur\AppData\Local\Temp\tmprf_4rzc5.
# 2025-08-16 09:36:05,625 - INFO - Opening browser.
# 2025-08-16 09:36:05,631 - INFO - Temp directory created: C:\Users\abdur\AppData\Local\Temp\tmpl2zawk2l.
# 2025-08-16 09:36:05,634 - INFO - Temporary directory at: C:\Users\abdur\AppData\Local\Temp\tmpl2zawk2l
# 2025-08-16 09:36:06,321 - INFO - Conforming 1 to file:///C:/Users/abdur/AppData/Local/Temp/tmprf_4rzc5/index.html
# 2025-08-16 09:36:06,323 - INFO - Waiting on all navigates
# 2025-08-16 09:36:08,239 - INFO - All navigates done, putting them all in queue.
# 2025-08-16 09:36:08,243 - INFO - Getting tab from queue (has 1)
# 2025-08-16 09:36:08,244 - INFO - Got E25E
# 2025-08-16 09:36:08,245 - INFO - Processing Comprehensive_Technical_Analysis_for_MSFT.png
# 2025-08-16 09:36:08,246 - INFO - Sending big command for Comprehensive_Technical_Analysis_for_MSFT.png.
# 2025-08-16 09:36:08,975 - INFO - Sent big command for Comprehensive_Technical_Analysis_for_MSFT.png.
# 2025-08-16 09:36:08,981 - INFO - Reloading tab E25E before return.
# 2025-08-16 09:36:09,208 - INFO - Putting tab E25E back (queue size: 0).
# 2025-08-16 09:36:09,209 - INFO - Waiting for all cleanups to finish.
# 2025-08-16 09:36:09,210 - INFO - Exiting Kaleido
# 2025-08-16 09:36:09,214 - INFO - TemporaryDirectory.cleanup() worked.
# 2025-08-16 09:36:09,215 - INFO - shutil.rmtree worked.
# 2025-08-16 09:36:09,217 - INFO - Cancelling tasks.
# 2025-08-16 09:36:09,218 - INFO - Exiting Kaleido/Choreo
# 2025-08-16 09:36:09,219 - INFO - Closing browser.
# 2025-08-16 09:36:09,224 - INFO - TemporaryDirectory.cleanup() worked.
# 2025-08-16 09:36:09,227 - INFO - shutil.rmtree worked.
# 2025-08-16 09:36:09,229 - INFO - Cancelling tasks.
# 2025-08-16 09:36:09,230 - INFO - Exiting Kaleido/Choreo
# 2025-08-16 09:36:09,231 - INFO - Closing browser.
# 2025-08-16 09:36:09,422 - INFO - TemporaryDirectory.cleanup() worked.
# 2025-08-16 09:36:09,425 - INFO - shutil.rmtree worked.
# 2025-08-16 09:36:09,431 - INFO - Comprehensive visualizations saved: ../visualizations\MSFT_comprehensive_analysis.html
# 2025-08-16 09:36:09,432 - INFO - PNG version saved: ../visualizations\MSFT_comprehensive_analysis.png
# 2025-08-16 09:36:09,433 - INFO - Loading stock data for GOOGL...
# 2025-08-16 09:36:09,592 - INFO - Successfully loaded 125 data points for GOOGL
# 2025-08-16 09:36:09,594 - INFO - Date range: 2025-02-18 00:00:00-05:00 to 2025-08-15 00:00:00-04:00
# 2025-08-16 09:36:09,595 - INFO - Calculating technical indicators...
# 2025-08-16 09:36:09,597 - INFO - Successfully calculated 30 technical indicators
# 2025-08-16 09:36:09,598 - INFO - Calculating financial metrics...
# 2025-08-16 09:36:09,602 - INFO - Successfully calculated 19 financial metrics
# 2025-08-16 09:36:09,602 - INFO - Creating comprehensive visualizations...
# 2025-08-16 09:36:09,626 - INFO - TemporaryDirectory.cleanup() worked.
# 2025-08-16 09:36:09,635 - INFO - shutil.rmtree worked.
# ===== GOOGL =====
# 2025-08-16 09:36:09,954 - INFO - Chromium init'ed with kwargs {}
# 2025-08-16 09:36:09,959 - INFO - Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# 2025-08-16 09:36:09,961 - INFO - Temp directory created: C:\Users\abdur\AppData\Local\Temp\tmphhpeysxx.
# 2025-08-16 09:36:09,964 - INFO - Opening browser.
# 2025-08-16 09:36:09,967 - INFO - Temp directory created: C:\Users\abdur\AppData\Local\Temp\tmpz_ww8wfl.
# 2025-08-16 09:36:09,970 - INFO - Temporary directory at: C:\Users\abdur\AppData\Local\Temp\tmpz_ww8wfl
# 2025-08-16 09:36:10,751 - INFO - Conforming 1 to file:///C:/Users/abdur/AppData/Local/Temp/tmphhpeysxx/index.html
# 2025-08-16 09:36:10,754 - INFO - Waiting on all navigates
# 2025-08-16 09:36:12,633 - INFO - All navigates done, putting them all in queue.
# 2025-08-16 09:36:12,636 - INFO - Getting tab from queue (has 1)
# 2025-08-16 09:36:12,637 - INFO - Got 9DD5
# 2025-08-16 09:36:12,639 - INFO - Processing Comprehensive_Technical_Analysis_for_GOOGL.png
# 2025-08-16 09:36:12,640 - INFO - Sending big command for Comprehensive_Technical_Analysis_for_GOOGL.png.
# 2025-08-16 09:36:13,214 - INFO - Sent big command for Comprehensive_Technical_Analysis_for_GOOGL.png.
# 2025-08-16 09:36:13,217 - INFO - Reloading tab 9DD5 before return.
# 2025-08-16 09:36:13,395 - INFO - Putting tab 9DD5 back (queue size: 0).
# 2025-08-16 09:36:13,395 - INFO - Waiting for all cleanups to finish.
# 2025-08-16 09:36:13,396 - INFO - Exiting Kaleido
# 2025-08-16 09:36:13,398 - INFO - TemporaryDirectory.cleanup() worked.
# 2025-08-16 09:36:13,400 - INFO - shutil.rmtree worked.
# 2025-08-16 09:36:13,401 - INFO - Cancelling tasks.
# 2025-08-16 09:36:13,403 - INFO - Exiting Kaleido/Choreo
# 2025-08-16 09:36:13,405 - INFO - Closing browser.
# 2025-08-16 09:36:13,411 - INFO - TemporaryDirectory.cleanup() worked.
# 2025-08-16 09:36:13,413 - INFO - shutil.rmtree worked.
# 2025-08-16 09:36:13,414 - INFO - Cancelling tasks.
# 2025-08-16 09:36:13,415 - INFO - Exiting Kaleido/Choreo
# 2025-08-16 09:36:13,416 - INFO - Closing browser.
# 2025-08-16 09:36:13,655 - INFO - TemporaryDirectory.cleanup() worked.
# 2025-08-16 09:36:13,656 - INFO - shutil.rmtree worked.
# 2025-08-16 09:36:13,660 - INFO - Comprehensive visualizations saved: ../visualizations\GOOGL_comprehensive_analysis.html
# 2025-08-16 09:36:13,662 - INFO - PNG version saved: ../visualizations\GOOGL_comprehensive_analysis.png

# %%
# Test the data types and fix
print("Checking data types before fix:")
print(f"Stock data columns: {list(analyzer.stock_data.columns)}")
print(f"Open dtype: {analyzer.stock_data['Open'].dtype}")
print(f"Close dtype: {analyzer.stock_data['Close'].dtype}")
print(f"High dtype: {analyzer.stock_data['High'].dtype}")
print(f"Volume dtype: {analyzer.stock_data['Volume'].dtype}")

print("\nSample data:")
print(analyzer.stock_data.head())

print("\nTesting type conversion:")
import numpy as np
close_prices = analyzer.stock_data['Close'].astype(np.float64).values
print(f"Converted close_prices dtype: {close_prices.dtype}")
print(f"Close prices shape: {close_prices.shape}")
print(f"Sample close prices: {close_prices[:5]}")

# %%
# Now test the fixed technical indicators calculation
print("Testing the fixed technical indicators calculation...")

# Reload the module to get the updated code
import importlib
import sys
sys.path.append(os.path.abspath(os.path.join('..')))
from src import quantitative_analysis
importlib.reload(quantitative_analysis)
from src.quantitative_analysis import QuantitativeAnalyzer

# Create a new analyzer instance with the fixed code
analyzer_fixed = QuantitativeAnalyzer("AAPL", period="6mo", interval="1d")
print("Loading data...")
if analyzer_fixed.load_stock_data():
    print("Data loaded successfully!")
    
    print("Calculating technical indicators with fixed code...")
    indicators = analyzer_fixed.calculate_technical_indicators()
    
    if indicators:
        print(f"\n✅ SUCCESS! Calculated {len(indicators)} indicators!")
        print("Available indicators:")
        for i, indicator in enumerate(indicators.keys()):
            print(f"{i+1:2d}. {indicator}")
        
        # Show some sample values
        print(f"\nSample RSI values (last 5): {indicators['RSI'][-5:]}")
        print(f"Sample SMA_20 values (last 5): {indicators['SMA_20'][-5:]}")
    else:
        print("❌ Still failed to calculate indicators")
else:
    print("❌ Failed to load data")
# Out:
# 2025-08-16 09:36:34,296 - INFO - Loading stock data for AAPL...
# Testing the fixed technical indicators calculation...
# Loading data...
# 2025-08-16 09:36:34,505 - INFO - Successfully loaded 125 data points for AAPL
# 2025-08-16 09:36:34,508 - INFO - Date range: 2025-02-18 00:00:00-05:00 to 2025-08-15 00:00:00-04:00
# 2025-08-16 09:36:34,510 - INFO - Calculating technical indicators...
# 2025-08-16 09:36:34,514 - INFO - Successfully calculated 30 technical indicators
# Data loaded successfully!
# Calculating technical indicators with fixed code...
#
# ✅ SUCCESS! Calculated 30 indicators!
# Available indicators:
#  1. SMA_20
#  2. SMA_50
#  3. SMA_200
#  4. EMA_12
#  5. EMA_26
#  6. RSI
#  7. STOCH_K
#  8. STOCH_D
#  9. WILLR
# 10. CCI
# 11. MACD
# 12. MACD_SIGNAL
# 13. MACD_HIST
# 14. ADX
# 15. AROON_UP
# 16. AROON_DOWN
# 17. BBANDS_UPPER
# 18. BBANDS_MIDDLE
# 19. BBANDS_LOWER
# 20. ATR
# 21. NATR
# 22. OBV
# 23. AD
# 24. ADOSC
# 25. DOJI
# 26. HAMMER
# 27. ENGULFING
# 28. ROC
# 29. MFI
# 30. ULTOSC
#
# Sample RSI values (last 5): [70.2433351  72.04930424 74.52957208 73.4800861  71.14574465]
# Sample SMA_20 values (last 5): [212.2490097  213.28786163 214.45827332 215.60817719 216.64064713]

# %%
# Test the complete analysis pipeline
print("Testing complete analysis pipeline...")

# Run complete analysis which should now work
success = analyzer_fixed.run_complete_analysis()

if success:
    print("✅ Complete analysis finished successfully!")
    print("\nGenerated files should be in:")
    print("- ../visualizations/ (charts)")
    print("- ../data/ (processed data and reports)")
    print("- ../models/ (if any models were saved)")
else:
    print("❌ Complete analysis failed")
# Out:
# 2025-08-16 09:36:43,982 - INFO - Starting complete quantitative analysis for AAPL...
# 2025-08-16 09:36:43,983 - INFO - Loading stock data for AAPL...
# 2025-08-16 09:36:44,095 - INFO - Successfully loaded 125 data points for AAPL
# 2025-08-16 09:36:44,097 - INFO - Date range: 2025-02-18 00:00:00-05:00 to 2025-08-15 00:00:00-04:00
# 2025-08-16 09:36:44,098 - INFO - Calculating technical indicators...
# 2025-08-16 09:36:44,100 - INFO - Successfully calculated 30 technical indicators
# 2025-08-16 09:36:44,100 - INFO - Calculating financial metrics...
# 2025-08-16 09:36:44,109 - INFO - Successfully calculated 19 financial metrics
# 2025-08-16 09:36:44,110 - INFO - Creating comprehensive visualizations...
# 2025-08-16 09:36:44,127 - INFO - TemporaryDirectory.cleanup() worked.
# 2025-08-16 09:36:44,130 - INFO - shutil.rmtree worked.
# Testing complete analysis pipeline...
# 2025-08-16 09:36:44,381 - INFO - Chromium init'ed with kwargs {}
# 2025-08-16 09:36:44,384 - INFO - Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# 2025-08-16 09:36:44,386 - INFO - Temp directory created: C:\Users\abdur\AppData\Local\Temp\tmp4u4rdpc1.
# 2025-08-16 09:36:44,387 - INFO - Opening browser.
# 2025-08-16 09:36:44,391 - INFO - Temp directory created: C:\Users\abdur\AppData\Local\Temp\tmp_zyzmkuu.
# 2025-08-16 09:36:44,394 - INFO - Temporary directory at: C:\Users\abdur\AppData\Local\Temp\tmp_zyzmkuu
# 2025-08-16 09:36:44,985 - INFO - Conforming 1 to file:///C:/Users/abdur/AppData/Local/Temp/tmp4u4rdpc1/index.html
# 2025-08-16 09:36:44,996 - INFO - Waiting on all navigates
# 2025-08-16 09:36:46,632 - INFO - All navigates done, putting them all in queue.
# 2025-08-16 09:36:46,634 - INFO - Getting tab from queue (has 1)
# 2025-08-16 09:36:46,636 - INFO - Got 0F98
# 2025-08-16 09:36:46,639 - INFO - Processing Comprehensive_Technical_Analysis_for_AAPL.png
# 2025-08-16 09:36:46,641 - INFO - Sending big command for Comprehensive_Technical_Analysis_for_AAPL.png.
# 2025-08-16 09:36:47,554 - INFO - Sent big command for Comprehensive_Technical_Analysis_for_AAPL.png.
# 2025-08-16 09:36:47,559 - INFO - Reloading tab 0F98 before return.
# 2025-08-16 09:36:48,580 - INFO - Putting tab 0F98 back (queue size: 0).
# 2025-08-16 09:36:48,582 - INFO - Waiting for all cleanups to finish.
# 2025-08-16 09:36:48,585 - INFO - Exiting Kaleido
# 2025-08-16 09:36:48,591 - INFO - TemporaryDirectory.cleanup() worked.
# 2025-08-16 09:36:48,593 - INFO - shutil.rmtree worked.
# 2025-08-16 09:36:48,596 - INFO - Cancelling tasks.
# 2025-08-16 09:36:48,597 - INFO - Exiting Kaleido/Choreo
# 2025-08-16 09:36:48,599 - INFO - Closing browser.
# 2025-08-16 09:36:48,609 - INFO - TemporaryDirectory.cleanup() worked.
# 2025-08-16 09:36:48,612 - INFO - shutil.rmtree worked.
# 2025-08-16 09:36:48,614 - INFO - Cancelling tasks.
# 2025-08-16 09:36:48,615 - INFO - Exiting Kaleido/Choreo
# 2025-08-16 09:36:48,616 - INFO - Closing browser.
# 2025-08-16 09:36:51,664 - WARNING - Resorting to unclean kill browser.
# 2025-08-16 09:36:52,393 - INFO - TemporaryDirectory.cleanup() worked.
# 2025-08-16 09:36:52,394 - INFO - shutil.rmtree worked.
# 2025-08-16 09:36:52,400 - INFO - Comprehensive visualizations saved: ../visualizations\AAPL_comprehensive_analysis.html
# 2025-08-16 09:36:52,402 - INFO - PNG version saved: ../visualizations\AAPL_comprehensive_analysis.png
# 2025-08-16 09:36:52,403 - INFO - Generating analysis report...
# 2025-08-16 09:36:52,408 - INFO - Analysis report generated: ../data\AAPL_analysis_report.md
# 2025-08-16 09:36:52,410 - INFO - Saving processed data...
# 2025-08-16 09:36:52,450 - INFO - Data with indicators saved: ../data\AAPL_data_with_indicators.csv
# 2025-08-16 09:36:52,454 - INFO - Financial metrics saved: ../data\AAPL_financial_metrics.csv
# 2025-08-16 09:36:52,457 - INFO - Metadata saved: ../data\AAPL_metadata.csv
# 2025-08-16 09:36:52,458 - INFO - Complete quantitative analysis finished successfully!
# 2025-08-16 09:36:52,458 - INFO - Generated files:
# 2025-08-16 09:36:52,459 - INFO - - Visualizations: ../visualizations/
# 2025-08-16 09:36:52,460 - INFO - - Data files: ../data/
# 2025-08-16 09:36:52,461 - INFO - - Analysis report: ../data\AAPL_analysis_report.md
# ✅ Complete analysis finished successfully!
#
# Generated files should be in:
# - ../visualizations/ (charts)
# - ../data/ (processed data and reports)
# - ../models/ (if any models were saved)
