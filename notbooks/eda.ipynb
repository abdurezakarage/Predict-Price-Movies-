# %%
import sys 
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from src.eda_analysis import NewsEDA

# %%
  # Initialize the EDA analysis
eda = NewsEDA("../data/raw_analyst/raw_analyst_ratings.csv")
# Out:
# Created visualizations directory: ../visualizations

# %%
# Run the complete analysis
eda.run_complete_analysis()
# Out:
# Starting comprehensive EDA analysis...
# Loading news data...
# Successfully loaded 1407328 news articles
# Data loaded and cleaned successfully!
#
# ==================================================
# DESCRIPTIVE STATISTICS
# ==================================================
# Total articles: 55,987
# Date range: 2011-04-27 21:01:48-04:00 to 2020-06-11 17:12:35-04:00
# Unique publishers: 225
# Unique stocks: 6204
#
# Headline Length Statistics:
#   Mean length: 80.0 characters
#   Median length: 63.0 characters
#   Min length: 12 characters
#   Max length: 512 characters
#
# Headline Word Count Statistics:
#   Mean words: 12.4 words
#   Median words: 10.0 words
#
# Top 10 Most Active Publishers:
#    1. Benzinga Newsdesk: 14,750 articles
#    2. Lisa Levin: 12,408 articles
#    3. ETF Professor: 4,362 articles
#    4. Paul Quintaro: 4,212 articles
#    5. Benzinga Newsdesk: 3,177 articles
#    6. Benzinga Insights: 2,332 articles
#    7. Vick Meyer: 2,128 articles
#    8. Charles Gross: 1,790 articles
#    9. Hal Lindon: 1,470 articles
#   10. Benzinga_Newsdesk: 1,239 articles
#
# Top 10 Most Covered Stocks:
#    1. ZX: 10 articles
#    2. A: 10 articles
#    3. AA: 10 articles
#    4. AAC: 10 articles
#    5. ZUMZ: 10 articles
#    6. AAL: 10 articles
#    7. AAMC: 10 articles
#    8. AAME: 10 articles
#    9. AAN: 10 articles
#   10. AAOI: 10 articles
#
# ==================================================
# TEXT ANALYSIS & TOPIC MODELING
# ==================================================
# Top 20 Most Common Keywords:
#    1. stocks: 12,794 occurrences
#    2. week: 9,029 occurrences
#    3. shares: 8,393 occurrences
#    4. trading: 6,575 occurrences
#    5. market: 5,482 occurrences
#    6. price: 5,046 occurrences
#    7. companies: 4,778 occurrences
#    8. target: 4,676 occurrences
#    9. several: 4,650 occurrences
#   10. sales: 4,429 occurrences
#   11. higher: 4,271 occurrences
#   12. estimate: 3,818 occurrences
#   13. lows: 3,741 occurrences
#   14. session: 3,394 occurrences
#   15. maintains: 3,266 occurrences
#   16. yesterday: 3,067 occurrences
#   17. which: 3,035 occurrences
#   18. reports: 3,016 occurrences
#   19. thursday: 2,927 occurrences
#   20. moving: 2,867 occurrences
#
# Financial Terms Analysis:
#   stock: 14,226 articles
#   low: 11,772 articles
#   pe: 10,156 articles
#   high: 7,694 articles
#   trading: 6,541 articles
#   market: 6,279 articles
#   price: 5,580 articles
#   target: 4,724 articles
#   etf: 4,482 articles
#   earnings: 2,277 articles
#   cap: 1,982 articles
#   increase: 1,124 articles
#   dividend: 985 articles
#   ratio: 873 articles
#   investment: 540 articles
#   fund: 524 articles
#   rating: 515 articles
#   profit: 464 articles
#   growth: 341 articles
#   revenue: 335 articles
#   return: 258 articles
#   risk: 249 articles
#   volume: 244 articles
#   loss: 228 articles
#   volatility: 221 articles
#   option: 213 articles
#   momentum: 196 articles
#   futures: 189 articles
#   analyst: 155 articles
#   support: 153 articles
#   decline: 149 articles
#   portfolio: 136 articles
#   hedge: 111 articles
#   chart: 74 articles
#   alpha: 52 articles
#   technical: 50 articles
#   valuation: 49 articles
#   trend: 49 articles
#   decrease: 39 articles
#   beta: 27 articles
#   fundamental: 26 articles
#   pattern: 14 articles
#   breakout: 9 articles
#   arbitrage: 6 articles
#   resistance: 6 articles
#   derivative: 5 articles
#   correlation: 1 articles
#
# Company/Industry Terms Analysis:
#   ai: 9,378 articles
#   ev: 7,025 articles
#   tech: 2,448 articles
#   financial: 2,043 articles
#   energy: 1,644 articles
#   oil: 1,280 articles
#   bank: 1,123 articles
#   technology: 879 articles
#   morgan: 828 articles
#   biotech: 817 articles
#   healthcare: 577 articles
#   pharmaceutical: 451 articles
#   gas: 385 articles
#   retail: 327 articles
#   software: 286 articles
#
# ==================================================
# TIME SERIES ANALYSIS
# ==================================================
# Publication Frequency Analysis:
#   Average articles per day: 22.1
#   Median articles per day: 9.0
#   Min articles per day: 1
#   Max articles per day: 973
#
# Articles by Day of Week:
#   Monday: 10,322 articles
#   Tuesday: 11,002 articles
#   Wednesday: 11,891 articles
#   Thursday: 12,688 articles
#   Friday: 9,381 articles
#   Saturday: 267 articles
#   Sunday: 436 articles
#
# Articles by Hour of Day:
#   00:00 - 00:59: 67 articles
#   01:00 - 01:59: 14 articles
#   02:00 - 02:59: 57 articles
#   03:00 - 03:59: 93 articles
#   04:00 - 04:59: 1,469 articles
#   05:00 - 05:59: 1,829 articles
#   06:00 - 06:59: 2,476 articles
#   07:00 - 07:59: 5,033 articles
#   08:00 - 08:59: 5,527 articles
#   09:00 - 09:59: 5,965 articles
#   10:00 - 10:59: 7,669 articles
#   11:00 - 11:59: 5,701 articles
#   12:00 - 12:59: 5,732 articles
#   13:00 - 13:59: 2,710 articles
#   14:00 - 14:59: 2,075 articles
#   15:00 - 15:59: 1,612 articles
#   16:00 - 16:59: 3,939 articles
#   17:00 - 17:59: 2,800 articles
#   18:00 - 18:59: 704 articles
#   19:00 - 19:59: 227 articles
#   20:00 - 20:59: 131 articles
#   21:00 - 21:59: 82 articles
#   22:00 - 22:59: 48 articles
#   23:00 - 23:59: 27 articles
#
# Monthly Publication Trends:
#   July 2019: 508 articles
#   August 2019: 712 articles
#   September 2019: 420 articles
#   October 2019: 686 articles
#   November 2019: 907 articles
#   December 2019: 875 articles
#   January 2020: 1,417 articles
#   February 2020: 2,356 articles
#   March 2020: 4,680 articles
#   April 2020: 4,616 articles
#   May 2020: 9,333 articles
#   June 2020: 5,990 articles
#
# Days with Unusually High Publication Counts (> 158.4):
#   2020-02-27: 275 articles
#   2020-02-28: 381 articles
#   2020-03-06: 281 articles
#   2020-03-11: 282 articles
#   2020-03-12: 973 articles
#   2020-03-19: 629 articles
#   2020-03-23: 375 articles
#   2020-03-24: 160 articles
#   2020-04-09: 164 articles
#   2020-04-13: 184 articles
#   2020-04-15: 186 articles
#   2020-04-16: 199 articles
#   2020-04-17: 194 articles
#   2020-04-20: 180 articles
#   2020-04-21: 233 articles
#   2020-04-22: 245 articles
#   2020-04-23: 265 articles
#   2020-04-24: 246 articles
#   2020-04-27: 283 articles
#   2020-04-28: 317 articles
#   2020-04-29: 449 articles
#   2020-04-30: 488 articles
#   2020-05-01: 385 articles
#   2020-05-04: 347 articles
#   2020-05-05: 478 articles
#   2020-05-06: 531 articles
#   2020-05-07: 749 articles
#   2020-05-08: 508 articles
#   2020-05-11: 485 articles
#   2020-05-12: 387 articles
#   2020-05-13: 549 articles
#   2020-05-14: 536 articles
#   2020-05-15: 322 articles
#   2020-05-18: 547 articles
#   2020-05-19: 332 articles
#   2020-05-20: 461 articles
#   2020-05-21: 333 articles
#   2020-05-22: 286 articles
#   2020-05-26: 628 articles
#   2020-05-27: 492 articles
#   2020-05-28: 465 articles
#   2020-05-29: 309 articles
#   2020-06-01: 484 articles
#   2020-06-02: 361 articles
#   2020-06-03: 720 articles
#   2020-06-04: 538 articles
#   2020-06-05: 932 articles
#   2020-06-08: 765 articles
#   2020-06-09: 804 articles
#   2020-06-10: 806 articles
#   2020-06-11: 544 articles
#
# ==================================================
# PUBLISHER ANALYSIS
# ==================================================
# Publisher Statistics (Top 15):
#                          article_count  avg_headline_length  \
# publisher
# Benzinga Newsdesk                14750                97.49
# Lisa Levin                       12408                44.39
# ETF Professor                     4362                44.02
# Paul Quintaro                     4212                84.11
# Benzinga Newsdesk                 3177               226.07
# Benzinga Insights                 2332                45.60
# Vick Meyer                        2128                75.75
# Charles Gross                     1790                81.06
# Hal Lindon                        1470                85.78
# Benzinga_Newsdesk                 1239                83.26
# Eddie Staley                      1003                75.72
# vishwanath@benzinga.com            924                77.76
# Shanthi Rexaline                   887               102.63
# Monica Gerson                      611                50.79
# Wayne Duggan                       465                56.93
#
#                          std_headline_length  avg_word_count  std_word_count  \
# publisher
# Benzinga Newsdesk                      52.96           14.99            7.91
# Lisa Levin                             16.31            7.08            2.15
# ETF Professor                          10.91            7.66            1.90
# Paul Quintaro                          36.62           12.99            5.66
# Benzinga Newsdesk                      66.10           34.73           10.21
# Benzinga Insights                      11.95            7.05            1.27
# Vick Meyer                             13.92           11.55            2.07
# Charles Gross                          37.10           12.41            5.98
# Hal Lindon                             39.65           12.86            5.97
# Benzinga_Newsdesk                      33.07           12.95            4.98
# Eddie Staley                           32.27           11.42            5.08
# vishwanath@benzinga.com                 9.54           12.04            1.21
# Shanthi Rexaline                       30.63           15.17            4.18
# Monica Gerson                          22.84            7.88            3.86
# Wayne Duggan                           17.61            9.45            2.72
#
#                          unique_stocks
# publisher
# Benzinga Newsdesk                 3771
# Lisa Levin                        3646
# ETF Professor                     1010
# Paul Quintaro                     1242
# Benzinga Newsdesk                  956
# Benzinga Insights                 1202
# Vick Meyer                        1228
# Charles Gross                     1023
# Hal Lindon                         844
# Benzinga_Newsdesk                  913
# Eddie Staley                       585
# vishwanath@benzinga.com            653
# Shanthi Rexaline                   428
# Monica Gerson                      370
# Wayne Duggan                       337
#
# Publisher Diversity Analysis:
#   Total publishers: 225
#   Publishers with >100 articles: 23
#   Publishers with >1000 articles: 11
#
# Email-based Publishers Analysis:
#   Articles from email publishers: 1199
#   Top email domains:
#     benzinga.com: 1196 articles
#     gmail.com: 3 articles
#
# Publisher Content Analysis:
#
#   Benzinga Newsdesk:
#     Total articles: 14,750
#     Average headline length: 97.5 characters
#     Covers 3771 unique stocks
#     Date range: 2016-06-23 08:56:09-04:00 to 2020-06-11 17:11:20-04:00
#
#   Lisa Levin:
#     Total articles: 12,408
#     Average headline length: 44.4 characters
#     Covers 3646 unique stocks
#     Date range: 2011-06-07 09:49:32-04:00 to 2020-06-11 12:19:17-04:00
#
#   ETF Professor:
#     Total articles: 4,362
#     Average headline length: 44.0 characters
#     Covers 1010 unique stocks
#     Date range: 2011-04-27 21:01:48-04:00 to 2020-06-11 15:25:36-04:00
#
#   Paul Quintaro:
#     Total articles: 4,212
#     Average headline length: 84.1 characters
#     Covers 1242 unique stocks
#     Date range: 2011-05-17 10:06:30-04:00 to 2018-05-31 15:49:22-04:00
#
#   Benzinga Newsdesk:
#     Total articles: 3,177
#     Average headline length: 226.1 characters
#     Covers 956 unique stocks
#     Date range: 2020-05-12 12:00:37-04:00 to 2020-06-11 14:26:26-04:00
#
# ==================================================
# CREATING VISUALIZATIONS
# ==================================================
# Visualizations saved as '../visualizations\news_eda_visualizations.png'
# Additional detailed plots saved
#
# ==================================================
# GENERATING COMPREHENSIVE REPORT
# ==================================================
# Comprehensive report saved as 'news_eda_report.md'
#
# ==================================================
# SAVING PROCESSED DATA FOR FURTHER ANALYSIS
# ==================================================
# Main cleaned dataset saved: ../data/processed_data\cleaned_news_data.csv
# Publisher statistics saved: ../data/processed_data\publisher_statistics.csv
# Daily publication counts saved: ../data/processed_data\daily_publication_counts.csv
# Stock coverage statistics saved: ../data/processed_data\stock_coverage_statistics.csv
# Top keywords saved: ../data/processed_data\top_keywords.csv
# Financial terms analysis saved: ../data/processed_data\financial_terms_analysis.csv
# Time features saved: ../data/processed_data\time_features.csv
# Dataset metadata saved: ../data/processed_data\dataset_metadata.csv
#
# All processed data saved in: ../data/processed_data/
#
# ==================================================
# EDA ANALYSIS COMPLETE!
# ==================================================
# Generated files:
# - ../visualizations/news_eda_visualizations.png
# - ../visualizations/monthly_trends.png
# - ../visualizations/top_publishers.png
# - news_eda_report.md
# - ../data/processed_data/ (processed data for further analysis)
